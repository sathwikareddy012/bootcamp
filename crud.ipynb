# %%
print("hello world")
# Out:
# hello world

# %%
list1=[]
for i in range(5):
    x=input("enter the elements")
    list1.append(x)
    print("list is:",list1)
# Out:
# enter the elements s
# list is: ['s']
# enter the elements a
# list is: ['s', 'a']
# enter the elements t
# list is: ['s', 'a', 't']
# enter the elements h
# list is: ['s', 'a', 't', 'h']
# enter the elements u
# list is: ['s', 'a', 't', 'h', 'u']

# %%
list=[6,7,8,9,0]
for i in list:
    print(i)
# Out:
# 6
# 7
# 8
# 9
# 0

# %%
list=[1,2,3,4,5]
x=input("enter elements to add:")
list.append(x)
print("updated list:",list)
# Out:
# enter elements to add: 6
# updated list: [1, 2, 3, 4, 5, '6']

# %%
list=[10,20,30,40]
index=int(input("enter index:"))
element=input("enter element:")
list.insert(index,element)
print("updated list:",list)
# Out:
# enter index: 4
# enter element: 45
# updated list: [10, 20, 30, 40, '45']

# %%
list=[10,20,30,40,50]
index=int(input("enter index to be remove:"))
list.pop(index)
list.pop(0)
list.pop(-1)
print("updated list:",list)
# Out:
# enter index to be remove: 4
# updated list: [20, 30]

# %%
list=[10,20,30,40,50]
element=int(input("element to remove:"))
list.remove(element)
print("updated list:",list)
# Out:
# element to remove: 30
# updated list: [10, 20, 40, 50]

# %%
list=[10,20,30,40]
del list
print("list deleted")
# Out:
# list deleted
